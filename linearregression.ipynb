# %% [markdown]
# <a href="https://colab.research.google.com/github/jyothi870/tejaswini5g5/blob/main/linearregression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
X = np.array([[-1], [-2], [-3], [-4], [-5]]) # Independent variable
Y = np.array([1, 2, 3, 4, 5]) # Dependent variable

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X)

# %%
plt.scatter(X, Y, color='blue') # Actual data points
plt.plot(X, Y_pred, color='red') # Regression line
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
print("Intercept (m0):", model.intercept_)
print("Corfficient (m1):", model.coef_)
# Out:
# Intercept (m0): 0.0
# Corfficient (m1): [1.]

# %%
plt.scatter(X, Y, color='blue')
plt.title("Generated Dataset of 100 Numbers")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y, color='blue') # Actual data points
plt.plot(X, Y, color='red') # Regression line
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
print("Intercept (m0):", model.intercept_)
print("Coefficient (m1):", model.coef_)
# Out:
# Intercept (m0): [0.82062015]
# Coefficient (m1): [[1.99204384]]

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
X = np.array([[72],[66],[64],[66],[40],[76],[72],[60],[70]])
Y = np.array([148,85,183,89,137,101,122,126,93])

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X)

# %%
plt.scatter (X, Y, color='green')
plt.plot(X, Y_pred, color='blue')
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
